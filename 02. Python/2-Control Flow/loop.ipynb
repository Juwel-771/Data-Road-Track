# %%
x = 10
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
## string
name = "Xenon"
for i in name:
    print(i)
# Out:
# X
# e
# n
# o
# n

# %%
## while
count = 0
while count < 5:
    print(count)
    count = count+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
## nested loop
for i in range(3):
    for j in range(2):
        print(f"i: {i} - j: {j}")
# Out:
# i: 0 - j: 0
# i: 0 - j: 1
# i: 1 - j: 0
# i: 1 - j: 1
# i: 2 - j: 0
# i: 2 - j: 1
