# %%
age = 20
if age>18:
    print("You are allowed to vote")
# Out:
# You are allowed to vote

# %%
age = 17
if age>18:
    print("You are allowed to vote")
else:
    print("Not allowed to VOTE")
# Out:
# Not allowed to VOTE
