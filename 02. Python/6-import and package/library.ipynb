# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 9
# apple

# %%
import os
print(os.getcwd())
# Out:
# g:\Data Analyst\Udemy - Complete Data Analyst Bootcamp From Basics To Advanced 2025-8\0. Learning\02. Python\6-import and package

# %%
import json

data = {"name" : "Meherab", "age" : 26}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Meherab", "age": 26}
# <class 'str'>
# {'name': 'Meherab', 'age': 26}
# <class 'dict'>

# %%
import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Meherab',32])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Meherab', '32']

# %%
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)

print(yesterday)
# Out:
# 2026-02-04 16:58:31.627917
# 2026-02-03 16:58:31.627917

# %%
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1770202719.636135
# 1770202721.6378796
