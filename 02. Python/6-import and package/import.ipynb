# %%
from math import sqrt,pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from package.maths import addition
addition(2,3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from package.maths import addition
#       2 addition(2,3)
#
# ModuleNotFoundError: No module named 'package.maths'

# %%
from package import maths
maths.addition(2,3)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from package import maths
#       2 maths.addition(2,3)
#
# ImportError: cannot import name 'maths' from 'package' (unknown location)
