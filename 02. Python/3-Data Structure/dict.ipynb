# %%
empty_dict = {}
print(empty_dict)
# Out:
# {}

# %%
student={"name" : "Meherab", "age": 26, "grade": "A+"}
print(student)
# Out:
# {'name': 'Meherab', 'age': 26, 'grade': 'A+'}

# %%
print(student['name'])
print(student['age'])
# Out:
# Meherab
# 26

# %%
print(student.get('name'))
print(student.get('age'))
# Out:
# Meherab
# 26

# %%
## adding new value
student["department"] = "CSE"
student["address"] = "India"

# %%
print(student)
# Out:
# {'name': 'Meherab', 'age': 26, 'grade': 'A+', 'department': 'CSE', 'address': 'India'}

# %%
## update value
student["address"] = "Bangladesh"

# %%
print(student)
# Out:
# {'name': 'Meherab', 'age': 26, 'grade': 'A+', 'department': 'CSE', 'address': 'Bangladesh'}

# %%
## Dictionaries method
keys=student.keys()
values=student.values()
item=student.items()

print(keys)
print(values)
print(item)
# Out:
# dict_keys(['name', 'age', 'grade', 'department', 'address'])
# dict_values(['Meherab', 26, 'A+', 'CSE', 'Bangladesh'])
# dict_items([('name', 'Meherab'), ('age', 26), ('grade', 'A+'), ('department', 'CSE'), ('address', 'Bangladesh')])
