# %%
import numpy as np
import pandas as pd

# %%
## basic series
array = np.arange(5)
array
# Out:
# array([0, 1, 2, 3, 4])

# %%
series=pd.Series(array)
series
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
series.values
# Out:
# array([0, 1, 2, 3, 4])

# %%
series.mean()
# Out:
# np.float64(2.0)

# %%
series.index = [10,20,30,40,50]

# %%
series
# Out:
# 10    0
# 20    1
# 30    2
# 40    3
# 50    4
# dtype: int64
